# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "id": "bbad0424",
   "metadata": {},
   "source": [
    "Actividad práctica: Visualización de datos en Python\n",
    "Objetivo\n",
    "\n",
    "Evaluar la capacidad del estudiante para analizar y comunicar información mediante gráficos, utilizando datos reales y apoyándose en:\n",
    "Cambiar por conceptos propios en donde aparezca el simbolo ##\n",
    "NumPy:##\n",
    "\n",
    "Pandas: ##\n",
    "\n",
    "Matplotlib:##\n",
    "\n",
    "Seaborn: ##\n",
    "Usando  el dataset de frutas antes trabajado y analizado, realice el cargue del 1. data set( ajunte evidencias),\n",
    "2. Exploración de datos (Pandas)( adjunte evidencias)\n",
    "3. Preparación de datos (adjunte evidencias)\n"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "ff40835e",
   "metadata": {},
   "source": [
    "4. Visualización con Matplotlib\n",
    "Actividad 1: Gráfico de barras. Realice las modificaciones que considere para realizar la grafia correspondiente.\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "26e42eef",
   "metadata": {},
   "outputs": [],
   "source": [
    "import matplotlib.pyplot as plt\n",
    "\n",
    "frutas_categoria.plot(kind=\"bar\")\n",
    "plt.title(\"Ventas por categoría\")\n",
    "plt.xlabel(\"Categoría\")\n",
    "plt.ylabel(\"Total ventas\")\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "b7706fa7",
   "metadata": {},
   "source": [
    "¿ Cual seria la intrepretación de la grafia?\n",
    "##"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "8b71e693",
   "metadata": {},
   "source": [
    "Actividad 2: Histograma\n",
    "¿Cuano es pertinente usarlo?\n",
    "##"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "b57343b2",
   "metadata": {},
   "outputs": [],
   "source": [
    "df[\"tamanio\"].hist()\n",
    "plt.title(\"Distribución de precios\")\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "2e5e09d0",
   "metadata": {},
   "source": [
    "¿ Cual es la comprensión de distribución de datos?\n",
    "##"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "e763333f",
   "metadata": {},
   "source": [
    "Visualización con Seaborn\n",
    "Actividad 3: Boxplot\n",
    "agregar el codigo pertienente para el uso de la libreria BoxPlot\n",
    "¿ Cuando es pertinenete usarlo?\n",
    "##\n",
    "¿ Que otras librerias serian utilies para la interpretación de este dataset?\n",
    "##"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "e564399c",
   "metadata": {},
   "source": [
    "“Cuenta la historia con datos”\n",
    "\n",
    "Cada estudiante debe:\n",
    "\n",
    "crear mínimo 3 gráficos diferentes\n",
    "\n",
    "interpretar cada uno\n",
    "\n",
    "redactar conclusiones"
   ]
  }
 ],
 "metadata": {
  "language_info": {
   "name": "python"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
